# %%
import numpy as np

# %%
new_array = np.random.randint(1,100,20)
new_array
# Out:
# array([82, 23, 41, 74, 94, 65, 99, 30, 97, 88, 61, 91, 59, 82, 66, 94, 92,
#        61, 90, 56], dtype=int32)

# %%
new_array > 25
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
new_array[new_array > 25]
# Out:
# array([82, 41, 74, 94, 65, 99, 30, 97, 88, 61, 91, 59, 82, 66, 94, 92, 61,
#        90, 56], dtype=int32)

# %%
new_array[new_array < 25]
# Out:
# array([23], dtype=int32)

# %%
matrix_array = np.array([[10,20],[20,30],[30,40]])
matrix_array
# Out:
# array([[10, 20],
#        [20, 30],
#        [30, 40]])

# %%
matrix_array.shape
# Out:
# (3, 2)

# %%
matrix_array.transpose()
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
matrix_array.T
# Out:
# array([[10, 20, 30],
#        [20, 30, 40]])

# %%
random_array = np.random.random((6,1))
random_array
# Out:
# array([[0.53297489],
#        [0.32584018],
#        [0.2574196 ],
#        [0.10024361],
#        [0.21303389],
#        [0.8411104 ]])

# %%
random_array.shape
# Out:
# (6, 1)

# %%
random_array.reshape(2,3)
# Out:
# array([[0.53297489, 0.32584018, 0.2574196 ],
#        [0.10024361, 0.21303389, 0.8411104 ]])

# %%
data = np.array([10,12,13,15,18,25,100,105])
mean = np.mean(data)

# %%
mean
# Out:
# np.float64(37.25)

# %%
std = np.std(data)
std
# Out:
# np.float64(37.9333296719389)

# %%
z_score = (data - mean) / std
z_score
# Out:
# array([-0.71836562, -0.66564154, -0.6392795 , -0.58655542, -0.50746929,
#        -0.322935  ,  1.65421809,  1.78602829])

# %%
data[z_score > 0]
# Out:
# array([100, 105])

# %%
A = np.array([[1,2],[3,4]])
B = np.array([8,19])
solution = np.linalg.solve(A,B)
solution
# Out:
# array([3. , 2.5])
