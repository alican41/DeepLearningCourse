# %%
import pandas as pd

# %%
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[ 0.73493252,  1.15312848,  0.89402664],
#        [ 0.67005067,  0.52432509, -0.20150439],
#        [ 1.51062725,  0.47569935, -0.41690988],
#        [-0.41650595, -0.3668097 ,  0.15429954]])

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0  0.734933  1.153128  0.894027
# 1  0.670051  0.524325 -0.201504
# 2  1.510627  0.475699 -0.416910
# 3 -0.416506 -0.366810  0.154300

# %%
data_frame[0]
# Out:
# 0    0.734933
# 1    0.670051
# 2    1.510627
# 3   -0.416506
# Name: 0, dtype: float64

# %%
new_df = pd.DataFrame(data, index = ["Ali", "Beyza", "Can", "Deniz"], columns = ["Salary", "Age", "Seniority"])
new_df
# Out:
#          Salary       Age  Seniority
# Ali    0.734933  1.153128   0.894027
# Beyza  0.670051  0.524325  -0.201504
# Can    1.510627  0.475699  -0.416910
# Deniz -0.416506 -0.366810   0.154300

# %%
new_df["Age"]
# Out:
# Ali      1.153128
# Beyza    0.524325
# Can      0.475699
# Deniz   -0.366810
# Name: Age, dtype: float64

# %%
new_df[["Age", "Salary"]]
# Out:
#             Age    Salary
# Ali    1.153128  0.734933
# Beyza  0.524325  0.670051
# Can    0.475699  1.510627
# Deniz -0.366810 -0.416506

# %%
new_df.loc["Ali"]
# Out:
# Salary       0.734933
# Age          1.153128
# Seniority    0.894027
# Name: Ali, dtype: float64

# %%
new_df.iloc[0]
# Out:
# Salary       0.734933
# Age          1.153128
# Seniority    0.894027
# Name: Ali, dtype: float64

# %%
new_df.iloc[:,2]
# Out:
# Ali      0.894027
# Beyza   -0.201504
# Can     -0.416910
# Deniz    0.154300
# Name: Seniority, dtype: float64

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#          Salary       Age  Seniority  Extra
# Ali    0.734933  1.153128   0.894027     10
# Beyza  0.670051  0.524325  -0.201504     10
# Can    1.510627  0.475699  -0.416910     10
# Deniz -0.416506 -0.366810   0.154300     10

# %%
new_df.drop("Extra", axis = 1, inplace = True)
# Extra sütununu sil axis = 1 sütun olduğunu belirtir inplace = True ise kalıcı olarak siler

# %%
new_df
# Out:
#          Salary       Age  Seniority
# Ali    0.734933  1.153128   0.894027
# Beyza  0.670051  0.524325  -0.201504
# Can    1.510627  0.475699  -0.416910
# Deniz -0.416506 -0.366810   0.154300

# %%
# axis = 0 ise satır siler axis = 1 ise sütun siler
new_df.drop("Beyza")
# Out:
#          Salary       Age  Seniority
# Ali    0.734933  1.153128   0.894027
# Can    1.510627  0.475699  -0.416910
# Deniz -0.416506 -0.366810   0.154300

# %%
new_df.loc["Ali"]
# Out:
# Salary       0.734933
# Age          1.153128
# Seniority    0.894027
# Name: Ali, dtype: float64

# %%
new_df.loc["Ali"]["Salary"]
# Out:
# np.float64(0.7349325247677199)

# %%
new_df.loc["Ali", "Salary"]
# Out:
# np.float64(0.7349325247677199)

# %%
new_df.loc["Ali", "Salary"] = 100

# %%
new_df
# Out:
#            Salary       Age  Seniority
# Ali    100.000000  1.153128   0.894027
# Beyza    0.670051  0.524325  -0.201504
# Can      1.510627  0.475699  -0.416910
# Deniz   -0.416506 -0.366810   0.154300

# %%
new_df > 0
# Out:
#        Salary    Age  Seniority
# Ali      True   True       True
# Beyza    True   True      False
# Can      True   True      False
# Deniz   False  False       True

# %%
new_df[new_df > 0]
# Out:
#            Salary       Age  Seniority
# Ali    100.000000  1.153128   0.894027
# Beyza    0.670051  0.524325        NaN
# Can      1.510627  0.475699        NaN
# Deniz         NaN       NaN   0.154300

# %%
new_df[new_df["Salary"] > 1]
# Out:
#          Salary       Age  Seniority
# Ali  100.000000  1.153128   0.894027
# Can    1.510627  0.475699  -0.416910

# %%
new_df.reset_index()
# Out:
#    index      Salary       Age  Seniority
# 0    Ali  100.000000  1.153128   0.894027
# 1  Beyza    0.670051  0.524325  -0.201504
# 2    Can    1.510627  0.475699  -0.416910
# 3  Deniz   -0.416506 -0.366810   0.154300

# %%
new_indices = ["A", "B", "C", "D"]
new_df["NewIndex"] = new_indices
new_df
# Out:
#            Salary       Age  Seniority NewIndex
# Ali    100.000000  1.153128   0.894027        A
# Beyza    0.670051  0.524325  -0.201504        B
# Can      1.510627  0.475699  -0.416910        C
# Deniz   -0.416506 -0.366810   0.154300        D

# %%
new_df.set_index("NewIndex", inplace = True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# A         100.000000  1.153128   0.894027
# B           0.670051  0.524325  -0.201504
# C           1.510627  0.475699  -0.416910
# D          -0.416506 -0.366810   0.154300

# %%
# multi index
first_index = ["Simpson", "Simpson", "Simpson", "South Park", "South Park", "South Park"]

# %%
inner_index = ["Homer", "Bart", "Marge", "Cartman", "Kenny", "Kyle"]

# %%
zipped_index = list(zip(first_index, inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values, index=zipped_index, columns = ["Age", "Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Bart       1.0
#             Marge      1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
big_df.loc["Simpson"]
# Out:
#        Age  Salary
# Homer  1.0     1.0
# Bart   1.0     1.0
# Marge  1.0     1.0

# %%
big_df.loc["Simpson"].loc["Homer"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Homer, dtype: float64
