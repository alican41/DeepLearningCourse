# %%
import pandas as pd
import torch
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("06-study_hours_grades.csv")

# %%
df.head()
# Out:
#    study_hours      grade
# 0     3.745401  30.203939
# 1     9.507143  57.878452
# 2     7.319939  46.368401
# 3     5.986585  39.330717
# 4     1.560186  14.843888

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   study_hours  50 non-null     float64
#  1   grade        50 non-null     float64
# dtypes: float64(2)
# memory usage: 928.0 bytes

# %%
df.describe()
# Out:
#        study_hours      grade
# count    50.000000  50.000000
# mean      4.459239  32.290305
# std       2.888832  14.431931
# min       0.205845  11.032281
# 25%       1.837670  21.062901
# 50%       4.360488  31.231858
# 75%       6.498549  41.683170
# max       9.699099  60.573564

# %%
df['study_hours'].values
# Out:
# array([3.74540119, 9.50714306, 7.31993942, 5.98658484, 1.5601864 ,
#        1.5599452 , 0.58083612, 8.66176146, 6.01115012, 7.08072578,
#        0.20584494, 9.69909852, 8.32442641, 2.12339111, 1.81824967,
#        1.8340451 , 3.04242243, 5.24756432, 4.31945019, 2.9122914 ,
#        6.11852895, 1.39493861, 2.92144649, 3.66361843, 4.56069984,
#        7.85175961, 1.99673782, 5.14234438, 5.92414569, 0.46450413,
#        6.07544852, 1.70524124, 0.65051593, 9.48885537, 9.65632033,
#        8.08397348, 3.04613769, 0.97672114, 6.84233027, 4.40152494,
#        1.22038235, 4.9517691 , 0.34388521, 9.09320402, 2.58779982,
#        6.62522284, 3.11711076, 5.20068021, 5.46710279, 1.84854456])

# %%
type(df['study_hours'].values)
# Out:
# numpy.ndarray

# %%
torch.tensor(df['study_hours'].values)
# Out:
# tensor([3.7454, 9.5071, 7.3199, 5.9866, 1.5602, 1.5599, 0.5808, 8.6618, 6.0112,
#         7.0807, 0.2058, 9.6991, 8.3244, 2.1234, 1.8182, 1.8340, 3.0424, 5.2476,
#         4.3195, 2.9123, 6.1185, 1.3949, 2.9214, 3.6636, 4.5607, 7.8518, 1.9967,
#         5.1423, 5.9241, 0.4645, 6.0754, 1.7052, 0.6505, 9.4889, 9.6563, 8.0840,
#         3.0461, 0.9767, 6.8423, 4.4015, 1.2204, 4.9518, 0.3439, 9.0932, 2.5878,
#         6.6252, 3.1171, 5.2007, 5.4671, 1.8485], dtype=torch.float64)

# %%
y = torch.tensor(df['grade'].values)
x = torch.tensor(df['study_hours'].values)

# %%
x
# Out:
# tensor([3.7454, 9.5071, 7.3199, 5.9866, 1.5602, 1.5599, 0.5808, 8.6618, 6.0112,
#         7.0807, 0.2058, 9.6991, 8.3244, 2.1234, 1.8182, 1.8340, 3.0424, 5.2476,
#         4.3195, 2.9123, 6.1185, 1.3949, 2.9214, 3.6636, 4.5607, 7.8518, 1.9967,
#         5.1423, 5.9241, 0.4645, 6.0754, 1.7052, 0.6505, 9.4889, 9.6563, 8.0840,
#         3.0461, 0.9767, 6.8423, 4.4015, 1.2204, 4.9518, 0.3439, 9.0932, 2.5878,
#         6.6252, 3.1171, 5.2007, 5.4671, 1.8485], dtype=torch.float64)

# %%
y
# Out:
# tensor([30.2039, 57.8785, 46.3684, 39.3307, 14.8439, 16.3600, 11.9829, 55.4231,
#         40.7430, 41.8775, 11.6774, 57.7253, 50.2683, 21.8403, 21.1532, 21.0328,
#         23.5337, 35.6194, 32.2598, 26.5125, 39.6343, 16.6034, 22.3946, 25.9257,
#         34.4286, 51.9713, 19.8397, 37.7188, 40.3440, 11.0323, 41.1000, 21.6023,
#         13.1809, 60.5736, 53.0421, 52.0637, 25.4048, 14.2856, 44.3952, 28.0325,
#         15.6626, 35.4731, 14.6752, 54.4295, 21.3220, 42.1226, 27.4164, 36.6609,
#         36.2760, 20.2693], dtype=torch.float64)

# %%
train_split = int(0.8 * len(x))
x_train, y_train = x[:train_split], y[:train_split]
x_test, y_test = x[train_split:], y[train_split:]

# %%
x_train
# Out:
# tensor([3.7454, 9.5071, 7.3199, 5.9866, 1.5602, 1.5599, 0.5808, 8.6618, 6.0112,
#         7.0807, 0.2058, 9.6991, 8.3244, 2.1234, 1.8182, 1.8340, 3.0424, 5.2476,
#         4.3195, 2.9123, 6.1185, 1.3949, 2.9214, 3.6636, 4.5607, 7.8518, 1.9967,
#         5.1423, 5.9241, 0.4645, 6.0754, 1.7052, 0.6505, 9.4889, 9.6563, 8.0840,
#         3.0461, 0.9767, 6.8423, 4.4015], dtype=torch.float64)

# %%
y_train
# Out:
# tensor([30.2039, 57.8785, 46.3684, 39.3307, 14.8439, 16.3600, 11.9829, 55.4231,
#         40.7430, 41.8775, 11.6774, 57.7253, 50.2683, 21.8403, 21.1532, 21.0328,
#         23.5337, 35.6194, 32.2598, 26.5125, 39.6343, 16.6034, 22.3946, 25.9257,
#         34.4286, 51.9713, 19.8397, 37.7188, 40.3440, 11.0323, 41.1000, 21.6023,
#         13.1809, 60.5736, 53.0421, 52.0637, 25.4048, 14.2856, 44.3952, 28.0325],
#        dtype=torch.float64)

# %%
x_test
# Out:
# tensor([1.2204, 4.9518, 0.3439, 9.0932, 2.5878, 6.6252, 3.1171, 5.2007, 5.4671,
#         1.8485], dtype=torch.float64)

# %%
y_test
# Out:
# tensor([15.6626, 35.4731, 14.6752, 54.4295, 21.3220, 42.1226, 27.4164, 36.6609,
#         36.2760, 20.2693], dtype=torch.float64)

# %%
plt.scatter(x_train, y_train, color='blue', s = 4, label='Training Data')
plt.scatter(x_test, y_test, color='red', s = 4, label='Test Data')
plt.xlabel('Study Hours')
plt.ylabel('Grade')
plt.legend()
plt.show()

# %%
from torch import nn

class SimpleLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.weights = nn.Parameter(torch.randn(1, requires_grad=True, dtype=torch.float))
        self.bias = nn.Parameter(torch.randn(1, requires_grad=True, dtype=torch.float))

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return self.weights * x + self.bias

# %%
torch.manual_seed(42)

model_0 = SimpleLinearRegressionModel()

# %%
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
with torch.inference_mode():
    y_pred = model_0(x_test)

# %%
plt.scatter(x_train, y_train, color='b', s = 5, label='Training Data')
plt.scatter(x_test, y_test, color='g', s = 5, label='Test Data')
plt.scatter(x_test, y_pred, color='r', s = 5, label='Predictions')
plt.xlabel('Study Hours')
plt.ylabel('Grade')
plt.legend()
plt.show()

# %%
loss_fn = nn.MSELoss()

optimizer = torch.optim.SGD(params=model_0.parameters(), lr=0.001)

# %%
torch.manual_seed(42)

epochs = 200
train_loss_values = []
test_loss_values = []
epoch_count = []

for epoch in range(epochs):
    model_0.train()

    y_pred = model_0(x_train)

    loss = loss_fn(y_pred, y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    model_0.eval()

    with torch.inference_mode():
        test_pred = model_0(x_test)
        test_loss = loss_fn(test_pred, y_test)

        if epoch & 5 == 0:
            epoch_count.append(epoch)
            train_loss_values.append(loss.detach().numpy())
            test_loss_values.append(test_loss.detach().numpy())
            print(f"Epoch: {epoch} | Loss: {loss} | Test Loss: {test_loss}")
# Out:
# Epoch: 0 | Loss: 1156.0767463081781 | Test Loss: 858.3088765088272
# Epoch: 2 | Loss: 907.883213839354 | Test Loss: 680.9339231802041
# Epoch: 8 | Loss: 445.0615950933129 | Test Loss: 347.84090985552996
# Epoch: 10 | Loss: 352.99125276114285 | Test Loss: 280.90521005460033
# Epoch: 16 | Loss: 181.26631068487106 | Test Loss: 154.6389929305529
# Epoch: 18 | Loss: 147.09195287313415 | Test Loss: 129.1006308895864
# Epoch: 24 | Loss: 83.31625299641897 | Test Loss: 80.57204878524264
# Epoch: 26 | Loss: 70.61197222215762 | Test Loss: 70.65347662055231
# Epoch: 32 | Loss: 46.86834245113659 | Test Loss: 51.58231656582005
# Epoch: 34 | Loss: 42.12614215182781 | Test Loss: 47.6186369531399
# Epoch: 40 | Loss: 33.22852214719357 | Test Loss: 39.85290344471839
# Epoch: 42 | Loss: 31.43920331397718 | Test Loss: 38.196048550561606
# Epoch: 48 | Loss: 28.04784760625472 | Test Loss: 34.854265257346
# Epoch: 50 | Loss: 27.353844189863754 | Test Loss: 34.11265188608324
# Epoch: 56 | Loss: 26.005213251658596 | Test Loss: 32.551923557805466
# Epoch: 58 | Loss: 25.717658065530618 | Test Loss: 32.18604154561516
# Epoch: 64 | Loss: 25.12736977128916 | Test Loss: 31.371240694261576
# Epoch: 66 | Loss: 24.990809892002737 | Test Loss: 31.16679618269875
# Epoch: 72 | Loss: 24.682548484552818 | Test Loss: 30.680691570399887
# Epoch: 74 | Loss: 24.602256546900758 | Test Loss: 30.549623754181795
# Epoch: 80 | Loss: 24.39939072812648 | Test Loss: 30.21729353754781
# Epoch: 82 | Loss: 24.340232302764633 | Test Loss: 30.121733180069917
# Epoch: 88 | Loss: 24.177251508934056 | Test Loss: 29.86607754014175
# Epoch: 90 | Loss: 24.12619565064586 | Test Loss: 29.788815212218672
# Epoch: 96 | Loss: 23.978797979614626 | Test Loss: 29.57383231531702
# Epoch: 98 | Loss: 23.931009395093362 | Test Loss: 29.50657873493717
# Epoch: 104 | Loss: 23.79017649453259 | Test Loss: 29.31441565103217
# Epoch: 106 | Loss: 23.74386082445062 | Test Loss: 29.252936230570818
# Epoch: 112 | Loss: 23.60624091009674 | Test Loss: 29.07426354712475
# Epoch: 114 | Loss: 23.56072961444814 | Test Loss: 29.01628475691594
# Epoch: 120 | Loss: 23.425072756357217 | Test Loss: 28.845983038742965
# Epoch: 122 | Loss: 23.38011596021797 | Test Loss: 28.790234175893072
# Epoch: 128 | Loss: 23.245951619669917 | Test Loss: 28.625407961182795
# Epoch: 130 | Loss: 23.20145409088186 | Test Loss: 28.57115999340207
# Epoch: 136 | Loss: 23.068600386630827 | Test Loss: 28.41012239698618
# Epoch: 138 | Loss: 23.024524694351918 | Test Loss: 28.35694399684516
# Epoch: 144 | Loss: 22.892909239633727 | Test Loss: 28.198697290823315
# Epoch: 146 | Loss: 22.849239154153125 | Test Loss: 28.146336070702894
# Epoch: 152 | Loss: 22.718826737753716 | Test Loss: 27.990283535313313
# Epoch: 154 | Loss: 22.675553449650284 | Test Loss: 27.938585865564438
# Epoch: 160 | Loss: 22.546324177177933 | Test Loss: 27.7843614972255
# Epoch: 162 | Loss: 22.50344320051805 | Test Loss: 27.73323066801455
# Epoch: 168 | Loss: 22.37538345042189 | Test Loss: 27.580616267497703
# Epoch: 170 | Loss: 22.33289056960002 | Test Loss: 27.529995550423074
# Epoch: 176 | Loss: 22.20598905912607 | Test Loss: 27.378850783252993
# Epoch: 178 | Loss: 22.16388060982312 | Test Loss: 27.328701513309362
# Epoch: 184 | Loss: 22.03812652016209 | Test Loss: 27.178939646592347
# Epoch: 186 | Loss: 21.996398271499793 | Test Loss: 27.1292413056604
# Epoch: 192 | Loss: 21.871780122066617 | Test Loss: 26.98080544547185
# Epoch: 194 | Loss: 21.8304284644384 | Test Loss: 26.93154193025387

# %%
plt.plot(epoch_count, train_loss_values, label='Train Loss')
plt.plot(epoch_count, test_loss_values, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Testing Loss')
plt.legend()

# %%
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([6.2443])), ('bias', tensor([2.0275]))])

# %%
model_0.eval()
with torch.inference_mode():
    y_preds_new = model_0(x_test)

# %%
plt.scatter(x_train, y_train, color='b', s = 5, label='Training Data')
plt.scatter(x_test, y_test, color='g', s = 5, label='Test Data')
plt.scatter(x_test, y_preds_new, color='r', s = 5, label='New Predictions')
plt.xlabel('Study Hours')
plt.ylabel('Grade')
plt.legend()
plt.show()
