# %%
import torch
import numpy as np

# %%
random_array = np.random.randn(3, 5)

# %%
random_array
# Out:
# array([[-0.78484662, -0.73694521, -0.62434927,  0.19653254, -1.40792843],
#        [ 0.88102828,  0.40191223,  0.34572934,  0.44653479,  1.24526121],
#        [ 0.31906746, -0.30322284,  0.78256832, -1.68548235, -0.26306502]])

# %%
type(random_array)
# Out:
# numpy.ndarray

# %%
random_array.shape
# Out:
# (3, 5)

# %%
random_array.ndim
# Out:
# 2

# %%
random_matrix = torch.rand(size=(3, 5))

# %%
random_matrix
# Out:
# tensor([[0.8868, 0.0193, 0.7325, 0.5506, 0.9020],
#         [0.5805, 0.7302, 0.1108, 0.6810, 0.2906],
#         [0.4080, 0.4161, 0.8342, 0.4959, 0.1946]])

# %%
random_matrix.ndim
# Out:
# 2

# %%
random_matrix.shape
# Out:
# torch.Size([3, 5])

# %%
random_matrix.dtype
# Out:
# torch.float32

# %%
random_image_tensor = torch.rand(size=(224, 224, 3))

# %%
random_image_tensor
# Out:
# tensor([[[9.9209e-01, 6.2081e-01, 7.8521e-01],
#          [2.5810e-01, 5.5498e-01, 8.6868e-01],
#          [1.0944e-01, 1.1984e-01, 7.0666e-01],
#          ...,
#          [4.4193e-01, 6.8637e-01, 3.8351e-01],
#          [1.0878e-01, 9.0432e-02, 9.5756e-01],
#          [7.2368e-01, 3.5963e-01, 6.4108e-01]],
#
#         [[7.7283e-01, 3.9820e-01, 4.0329e-01],
#          [4.6880e-01, 3.3985e-01, 9.5267e-01],
#          [4.2847e-01, 2.7851e-01, 2.5515e-01],
#          ...,
#          [6.4360e-02, 5.6698e-01, 7.3739e-01],
#          [8.7198e-01, 4.7002e-01, 2.7106e-01],
#          [7.3687e-01, 5.7377e-01, 1.0832e-01]],
#
#         [[6.3988e-01, 2.8705e-01, 6.3053e-01],
#          [3.8831e-01, 1.3798e-04, 6.3602e-01],
#          [5.4215e-01, 2.5995e-01, 2.0494e-01],
#          ...,
#          [7.5018e-02, 2.7277e-01, 8.9939e-01],
#          [8.7854e-01, 7.1321e-02, 8.0671e-01],
#          [6.3456e-01, 7.1715e-02, 8.5009e-02]],
#
#         ...,
#
#         [[6.2072e-01, 3.1804e-01, 6.7111e-01],
#          [9.5325e-01, 3.6155e-01, 7.0188e-01],
#          [3.0470e-02, 8.8084e-01, 7.3767e-01],
#          ...,
#          [1.1091e-01, 6.7513e-02, 1.2864e-01],
#          [5.4772e-01, 5.5920e-02, 5.8422e-01],
#          [7.2062e-01, 6.4814e-01, 3.7167e-01]],
#
#         [[6.0765e-01, 7.8590e-01, 4.1642e-01],
#          [6.2986e-01, 2.7469e-01, 4.2050e-01],
#          [1.4929e-01, 5.3933e-01, 8.7438e-01],
#          ...,
#          [2.9536e-01, 1.8813e-01, 2.0038e-01],
#          [1.2968e-01, 7.4191e-01, 6.1222e-01],
#          [9.0470e-01, 8.2318e-02, 5.6110e-01]],
#
#         [[3.0655e-01, 2.5846e-01, 3.9809e-01],
#          [7.9060e-01, 6.6830e-01, 9.5082e-01],
#          [5.5692e-01, 9.2094e-01, 6.9889e-01],
#          ...,
#          [4.8356e-01, 2.9892e-01, 6.7684e-01],
#          [2.5462e-01, 3.2081e-01, 6.6726e-01],
#          [9.6089e-01, 7.2789e-01, 4.5151e-01]]])
